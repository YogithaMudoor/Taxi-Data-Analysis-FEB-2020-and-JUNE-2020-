# %% [markdown]
# <a href="https://colab.research.google.com/github/YogithaMudoor/Taxi-Data-Analysis-FEB-2020-and-JUNE-2020-/blob/main/Taxi_Data_Analysis_comparison_between_FEB_2020_and_JUNE_2020.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **COMPARISON OF FINAL RESULTS FROM EDA OF JUNE 2020 AND FEB 2020**<br>
# Following insights would be useful for our company's product launch in New York
#
# **Fare_amount JUNE 2020**- most of the fare amount is within 10 dollar value as is shown by the median value. Though there are some significant outliers, the maximum of which is 941 dollars.<br>
#
# **Fare amount FEB 2020**-most of the fare amount is within 10 dollar value as is shown by the median value. Though there are some significant outliers, the maximum of which is 6000 dollars.
#
#
# ---
# **Duration JUNE 2020** - most of the values in duration is within 10 minutes range as is shown by the median value. We do have some outliers which are beyond the range of 1000 minutes.
#
# **Duration  FEB 2020**- most of the values in duration is within 10 minutes range as is shown by the median value. We do have some outliers which are beyond the range of 1000 minutes.
#
#
# ---
# **Trip_distance JUNE 2020**- most of the trip_distance is within 1.87 miles value as is shown by the median. The outlier in this case is quite less.<BR>
# **Trip_distance FEB 2020** - most of the trip_distance is within 1.6 miles value as is shown by the median. The outlier in this case is quite less.
#
#
#
# ---
# **Busiest pickup and drop off time JUNE 2020**
#  Peak hour for the pick up and drop off is afternoon 12pm to 5PM. The busiest time is 3PM.<br>
#
# **Busiest pickup and drop off time FEB 2020**Peak hour for the pick up and drop off is around evening from 5 to 7. The busiest time is 6PM
#
#
# ---
# **Heavy taxi utilised day June 2020**
# Sunday has the lowest taxi uses.
#  Weekdays except wednesday have heavy taxi uses.
#  Among weekends Staturday also lowest taxi uses.
#
# **Heavy taxi utilised day FEB  2020**
# *Sunday has the lowest taxi uses.
#  Weekdays except monday have heavy taxi uses.
#  Among weekends Staturday has the highest taxi uses.
#
#
# ---
# **Busiest routes JUNE 2020**
# Five busiest route are following: 237-236 264-264 236-237 236-236 75-74
# **Busiest routes FEB 2020**
# Five busiest route are following: 264-264 237-237 236-237 236-236 237-236
#
#
# ---
# **Highly preferred payment mode JUNE 2020**
# Credit card is the most preferred mode of payment followed by cash.
# **Highly preferred payment mode FEB 2020**
# Credit card is the most preferred mode of payment followed by cash.
#
#
# ---
# **Busiest location JUNE 2020**
# The busiest location in terms of pickup and dropoff are 186,75, 236 and 237<br>
# **Busiest location FEB 2020**
# The busiest location in terms of pickup are 161, 236 and 237
#
# ---
#
#
#
# **Together the maximum number of passengers per journey JUNE 2020**
# Mostly 1 or 2 passenger avail the cab. Group rides are less common.<br>
# **Together the maximum number of passengers per journey FEB 2020**
# Mostly 1 or 2 passenger avail the cab. Group rides are less common.
#
#
# ---
#
#
# **Applicability of taxes JUNE 2020**
# From the hour 12AM to 5AM the median taxes seem to be lower than other hours.
# Overnight charges are not applied between 9PM to 12AM
# Evening has higher variability in taxes and the taxes are usually high.<br>
# **Applicability of taxes FEB 2020**
# From the hour 8PM to 5AM the median taxes seem to be a bit higher than other hours, it may be due to some overnight surcharges.Evening from 4PM to 7PM have quite variable taxes and is a bit higher than other times, it may be due to higher traffic charges
#
#
# ---
# **Long distance travel time of the day JUNE 2020**
# Early morning and night hours of 11 PM TO morning 5PM have longer duration trips
#
# **Long distance travel time of the day FEB 2020**
# Early morning hours of 6AM to 7AM have shorter duration trips and night 2AM to 3AM
#
#
# ---
#
# **Tip_amount JUNE 2020**
# tip_amount - most of the tip amount is within 1.5 dollar as is shown by the median value. Though again here too we have outliers, the maximum of which is around 422 dollars.
#
#
# **Tip_amount FEB 2020** - most of the tip amount is within 1-2.5 dollar as is shown by the median value. Though again here too we have outliers, the maximum of which is around 550 dollars.

# %% [markdown]
# **HIGHLIGHTS OF COMPARISON BETWEEN EDA OF JUNE 2020 AND FEB 2020**
#
#
#
# *   From the collected data we can say more people traveled by taxi in the month of Feb(i.e prepandemic) than the month of june(i.e postpandemic)
#
# *   Max fare amount of feb month  is 6000 dollars which is too high than the max fare amount of june 2020
#
#
# *  During the pre pandemic people have travelled much during evening time but after pandemic people have not travelled much during evening that may be due to some restrictions of COVID and people were taking care of their health.
#
# *   There was only one passenger in 70% of the travel during post pandemic<br>
#     There was only one passenger in around 71% of the travel during prepandemic
#     So it says people usually prefer to travel alone in a cab
#
# *   People always prefer credit card payment first then cash payment<br>
#     During prepandemic around 75% of travellers used credit card payment<br>
#     During postpandemic around 59% of travellers used credit card system
#
#
# *  264-264 237-237 236-237 236-236 237-236  are the busiest routes so most of the people travels through these routes.
#
#
# *   People have travelled much for long distances during night time in postpandemic compared to prepandemic
#
# *   236 and 237 are the busiest locarions ever
